# %% [markdown]
# # Try it: complexity and generalization
#
# A model that fits the **training** data almost perfectly can still fail on **new** data. That gap is the heart of **generalization**.
#
# Here we fit a polynomial of degree `d` to a noisy curve:
#
# - Low degree: the fit is simple (maybe too simple).
# - High degree: the curve can wiggle through every training point (overfitting).
#
# We report **RMSE** (root mean squared error) on the training set and on a held-out test set. Watch which one keeps improving as degree grows.

# %% [markdown]
# ## Try it yourself
#
# The explorer below uses a fixed train/test split of the same noisy data.
#
# - Start at **degree 1**, then walk up toward **12**.
# - Watch the red curve and the two RMSE numbers in the title.
# - Around which degrees is **test** RMSE still improving? When does it get worse while **train** RMSE keeps falling?

# %% [markdown]
# :::{important} This demo needs a running kernel
# The explorer is interactive only when the notebook is running on a live kernel. Click the launch button at the top of the page (for example, Binder) to start one, then run the cell below and move the degree slider.
# :::

# %%
from utils_complexity import run_complexity_demo

run_complexity_demo()

# %% [markdown]
# :::{note} Takeaways
# - Training error alone is not enough — we care about performance on unseen data.
# - Extra complexity can help up to a point, then hurt generalization (overfitting).
# - Holding out a test set is one simple way to check whether a fancier model is actually better.
# :::
